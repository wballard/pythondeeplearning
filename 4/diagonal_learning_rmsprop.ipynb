# %% [markdown]
# Now we'll explore another optimizer RMSProp. This differs in that it adjusts the actual learning rate while it learns.

# %%
import mxnet as mx
from mxnet import nd, autograd, gluon
import matplotlib.pyplot as plt
from matplotlib import animation, rc
from IPython.display import HTML
# Out:
# /opt/conda/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# Again, this is our objective function -- we'll visualize it again to jog our memory!

# %%
size = 16
batch_size = 32
objective = nd.ones(size).diag()
plt.imshow(objective.asnumpy(), cmap='binary')

# %% [markdown]
# Now - a set of random inputs and outputs, including a data loader to dispense mini batches.

# %%
inputs = [nd.random.uniform(shape=(size, size)) for i in range(1024)]
outputs = [input * objective for input in inputs]
dataset = mx.gluon.data.dataset.ArrayDataset(inputs, outputs)
data_loader = mx.gluon.data.DataLoader(dataset, batch_size=batch_size)

# %% [markdown]
# OK -- now we'll set up to learn, starting with a random matrix.

# %%
#everything will be run on the CPU context, these are really simple models
ctx = mx.cpu()

params = gluon.parameter.ParameterDict('_')
learned_diagonal = params.get('learned_diagonal', grad_req='write', shape=(size, size))
params.initialize(ctx=ctx)
plt.imshow(learned_diagonal.data().asnumpy(), cmap='binary')

# %% [markdown]
# Our simple network -- again same as the last video, we'll only be changing the training algorithm.

# %%
def net(input):
    return input * learned_diagonal.data()

def learn(net, optimizer):
    params.initialize(ctx=ctx, force_reinit=True)
    epochs = 10
    #initial value, so we can see where we started
    learning_steps = []
    learning_steps.append(learned_diagonal.data().asnumpy())
    #simple loss function
    square_loss = gluon.loss.L2Loss()
    losses = []
    for e in range(epochs):
        for input_batch, output_batch in dataset:
            with autograd.record():
                predicted = net(input_batch)
                loss = square_loss(predicted, output_batch)
                loss.backward()
            optimizer.step(input_batch.shape[0])
        learning_steps.append(learned_diagonal.data().asnumpy())

        print("Loss: {0}".format(nd.sum(loss).asscalar()), flush=True)
        losses.append(nd.sum(loss).asscalar())
    return learning_steps, losses

# %% [markdown]
# And here is a function to make an animated bitmap of the learning. At each step, we are simply showing an image, and then joining it together with the `FuncAnimation` class.

# %%
def animate(frames):
    fig, ax = plt.subplots(figsize=(4, 4))

    def update(i):
        ax.imshow(frames[i], cmap='binary')
        ax.set_axis_off()

    anim = animation.FuncAnimation(fig, update, frames=len(frames), interval=200)
    plt.close()
    return HTML(anim.to_jshtml())

# %%
optimizer = gluon.Trainer(params, 'rmsprop')
learning_steps, losses = learn(net, optimizer)
animate(learning_steps)
# Out:
# Loss: 0.012662110850214958
# Loss: 4.4582025571227035e-11
# Loss: 7.926341874520126e-14
# Loss: 7.926341874520126e-14
# Loss: 7.926341874520126e-14
# Loss: 7.926341874520126e-14
# Loss: 7.926341874520126e-14
# Loss: 7.926341874520126e-14
# Loss: 7.926341874520126e-14
# Loss: 7.926341874520126e-14
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgeb22caef346a4cb1af645b050ff51a43">
#     <br>
#     <input id="_anim_slidereb22caef346a4cb1af645b050ff51a43" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="animeb22caef346a4cb1af645b050ff51a43.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animeb22caef346a4cb1af645b050ff51a43.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="animeb22caef346a4cb1af645b050ff51a43.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="animeb22caef346a4cb1af645b050ff51a43.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="animeb22caef346a4cb1af645b050ff51a43.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="animeb22caef346a4cb1af645b050ff51a43.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="
wAATECBMQIEBAjQECMAAExAgTECBAQI0BAjAABMSP608wDAwOl3ZYtW5o3Tz75ZOnW\
# W2+91bz57bffSreWL19e2k2dOrV58/nnn5duffrpp6XdqlWrmjezZ88u3aq8MHvvvfeWbn399del\
# XeWTznv27CndSvIEBMQIEBAjQECMAAExAgTECBAQI0BAjAABMQIExAgQECNAQIwAATECBMSM6Lfh\
# T5w4UdotXbq0edPf31+6NX78+ObN4OBg6daaNWtKu2nTpjVvvvvuu9Kt119/vbTbv39/82bbtm2l\
# W0ePHm3e7Nu3r3Sr+oZ6X19f86b62xKSPAEBMQIExAgQECNAQIwAATECBMQIEBAjQ

# %% [markdown]
# Wow! Changing just the learning optimizer and we nearly instantly learn the function.
#
# Now we can take a look at the loss. Basically, this converges to effectively zero loss right away.

# %%
import numpy as np
def plot_loss(total_loss):
    x_axis = np.linspace(0, len(total_loss), len(total_loss), endpoint=True)
    plt.semilogy(x_axis, total_loss)
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.show()

# %%
plot_loss(losses)

# %% [markdown]
# Interesting! Way less data, and effectively an 'instant' learning. One more algorithm to try -- ADAM.

# %%
optimizer = gluon.Trainer(params, 'adam')
learning_steps, losses = learn(net, optimizer)
animate(learning_steps)
# Out:
# Loss: 0.022266294807195663
# Loss: 0.0008778957417234778
# Loss: 3.285323828094988e-06
# Loss: 3.894898981116057e-08
# Loss: 3.6509087419922537e-10
# Loss: 5.184890383702623e-08
# Loss: 1.9171304543874612e-09
# Loss: 4.421659127729072e-08
# Loss: 3.9115825245517044e-08
# Loss: 3.1782775522515294e-08
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgabfe5caa741c4a4f9d7bae27548f58c7">
#     <br>
#     <input id="_anim_sliderabfe5caa741c4a4f9d7bae27548f58c7" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="animabfe5caa741c4a4f9d7bae27548f58c7.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animabfe5caa741c4a4f9d7bae27548f58c7.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="animabfe5caa741c4a4f9d7bae27548f58c7.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="animabfe5caa741c4a4f9d7bae27548f58c7.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="animabfe5caa741c4a4f9d7bae27548f58c7.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="animabfe5caa741c4a4f9d7bae27548f58c7.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="animabfe5caa741c4a4f9d7bae27548f58c7.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="animabfe5caa741c4a4f9d7bae27548f58c7.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="animabfe5caa741c4a4f9d7bae27548f58c7.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="animabfe5caa741c4a4f9d7bae27548f58c7.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_selectabfe5caa741c4a4f9d7bae27548f58c7" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgabfe5caa741c4a4f9d7bae27548f58c7";
#     var slider_id = "_anim_sliderabfe5caa741c4a4f9d7bae27548f58c7";
#     var loop_select_id = "_anim_loop_selectabfe5caa741c4a4f9d7bae27548f58c7";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvhp/UCwAACZlJREFUeJzt3c2LlnUbxvFrHs3GcshZZEG1cdFE\
# BWoUSpQutIYmqLAXgkQJX4oKwtqMRYWE4aYgA8uS6MW0nRlEQRDYIqEIMoUSRXJQGio1elE08H7+\
# goLfydAxPM/nsz84b1S+XJvLq6/X6/U6gID/pH8A8P9LgIAYAQJiBAiIESAgRoCAGAECYgQIiBEg\
# IEaAgBgBAmIECIgRICBGgIAYAQJiBAiIESAgRoCAGAECYgQIiBEgIEaAgBgBAmIECIgRICBGgIAY\
# AQJiBAiIESAgRoCAGAECYgQIiBEgIEaAgJip6R/wT+69997SbnR0tHmzZMmS0q3PPvusefP111+X\
# bs2YMaO0mzJlSvNmaGiodOvs2bOl3c0339y82bhxY+nW1q1bmzeLFy8u3Vq1alVpt2nTpuZN5d99\
# 13Xd7NmzS7uJ4AkIiBEgIEaAgBgBAmIECIgRICBGgIAYAQJiBAiIESAgRoCAGAECYvp6vV4v/SP+\
# zuDgYGlXeblu5cqVpVsDAwPNmy+//LJ0a9myZaXdX3/91bypvkT51ltvlXYnTpxo3mzevLl0a9u2\
# bc2byt9z19VfqK68QPzHH3+Ubn388cel3UTwBATECBAQI0BAjAABMQIExAgQECNAQIwAATECBMQI\
# EBAjQECMAAExk/pl1JGRkdLuqaeeat48++yzpVs33HBD8+bHH38s3RofHy/t5s+f37y5/PLLS7cu\
# ueSS0u7WW29t3uzevbt064orrmjenDlzpnTr4MGDpd3+/fubN48//njp1sUXX1zaTQRPQECMAAEx\
# AgTECBAQI0BAjAABMQIExAgQECNAQIwAATECBMQIEBAjQEDM1PQP+Ccvv/xyaVd5i/7IkSOlWzNm\
# zGje9PX1lW79/vvvpd3555/fvBkdHS3dWr9+fWk3PDzcvNm1a1fpVuXT2Hv27Cndqr4Nv2nTpuZN\
# 9a325H+I4QkIiBEgIEaAgBgBAmIECIgRICBGgIAYAQJiBAiIESAgRoCAGAECYib1p5kHBgZKu8oL\
# ouvWrSvd+u6775o3H330UenWli1bSrtTp041b06cOFG69f7775d2hw4dat4888wzpVuVf/K33357\
# 6dY777xT2r399tvNmx9++KF06/Tp06XdRPAEBMQIEBAjQECMAAExAgTECBAQI0BAjAABMQIExAgQ\
# ECNAQIwAATECBMRM6k8zT51a+3k7d+5s3lTeoO+6rjt69Gjzpvq53uqnd4eGhpo306dPL9164IEH\
# SruTJ082b5YtW1a6NT4+3rx58cUXS7eef/750u7cuXPNm+3bt5duJXkCAmIECIgRICBGgIAYAQJi\
# BAiIESAgRoCAGAECYgQIiBEgIEaAgBgBAmIm9bfhq98Zf/TRR5s3ixYtKt3at29f8+aWW24p3Zo5\
# c2ZpNzIy0ry55pprSrcGBwdLu76+vubNq6++Wrp13333NW8qb9B3Xe1/Iui6rrvsssuaN9OmTSvd\
# GhsbK+0mgicgIEaAgBgBAmIECIgRICBGgIAYAQJiBAiIESAgRoCAGAECYgQIiJnUL6NWP0X8008/\
# NW+qLzbecccdzZs1a9aUbj300EOl3cKFC5s3N954Y+nW9ddfX9qdd955zZv+/v7SrUceeaR5c//9\
# 95duVf8cN2zY0LyZN29e6Vbl8+ITxRMQECNAQIwAATECBMQIEBAjQECMAAExAgTECBAQI0BAjAAB\
# MQIExAgQEDM1/QP+ybp160q7w4cPN2+qn7W9+uqrmzd79+4t3bryyitLuwsvvLB5U/2fCKqfMB4Y\
# GGjeVN/ivvTSS5s3w8PDpVv79+8v7SqfF3/44YdLt5I8AQExAgTECBAQI0BAjAABM

# %%
plot_loss(losses)

# %% [markdown]
# Again, a very good solution -- and a two epochs before we recognize our diagonal. Look at the loss however, it bounces around. Adam has a bit more -- liveliness -- which can help it to not get stuck in 'valleys' in your data. Now our simple problem here -- the diagonal - is a solid ridge, there aren't any other ridges or valleys in our data to get stuck.
#
# So -- in addition to parameters, you can also change the actual learning algorithm as a *hyperparameter*. For different data, different learning algorithms can lead to better results!
